# %% [markdown]
# <h1>Brute Force</h1>

# %%
def bestSum(m, bestSumlist):
    if m == 0:
        return []
    if m < 0:
        return None
    
    shortest_comb = None
    
    for i in bestSumlist:
        remainder = m - i
        remainder_combination = bestSum(remainder, bestSumlist)
        if remainder_combination != None:
            remainder_combination_copy = copy.deepcopy(remainder_combination)
            remainder_combination_copy.append(i) 
            combination = remainder_combination_copy
            if shortest_comb == None or len(shortest_comb) > len(combination):
                shortest_comb = combination
            
    return shortest_comb

print(bestSum(100,[1,2,5,25]))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-449f5d110cd8> in <module>
#      19     return shortest_comb
#      20
# ---> 21 print(bestSum(100,[1,2,5,25]))
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#       9     for i in bestSumlist:
#      10         remainder = m - i
# ---> 11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
#      13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#
# <ipython-input-24-449f5d110cd8> in bestSum(m, bestSumlist)
#      11         remainder_combination = bestSum(remainder, bestSumlist)
#      12         if remainder_combination != None:
# ---> 13             remainder_combination_copy = copy.deepcopy(remainder_combination)
#      14             remainder_combination_copy.append(i)
#      15             combination = remainder_combination_copy
#
# ~\anaconda3\lib\copy.py in deepcopy(x, memo, _nil)
#     175     if y is not x:
#     176         memo[d] = y
# --> 177         _keep_alive(x, memo) # Make sure x lives at least as long as d
#     178     return y
#     179
#
# KeyboardInterrupt:

# %% [markdown]
# <h1>Memoizatioin</h1>

# %%
import copy
def bestSum(m, bestSumlist):
    if m in d: return d[m]
    if m == 0:
        return []
    if m < 0:
        return None
    
    shortest_comb = None
    
    for i in bestSumlist:
        remainder = m - i
        remainder_combination = bestSum(remainder, bestSumlist)
        if remainder_combination != None:
            remainder_combination_copy = copy.deepcopy(remainder_combination)
            remainder_combination_copy.append(i) 
            combination = remainder_combination_copy
            if shortest_comb == None or len(shortest_comb) > len(combination):
                shortest_comb = combination
    d[m] = shortest_comb
    return shortest_comb

d = dict()
print(bestSum(100,[1,2,5,25]))
# Out:
# [25, 25, 25, 25]

# %%
import copy
def canSum(target,num):
    arr = [None]*(target+1)
    arr[0] = [[]]
    for i in range(target+1):
        print(i)
        if arr[i] != None:
            for j in num:
                if i+j <= target:
                    comb = [[j]+u for u in arr[i]]
                    if arr[i+j] == None or  len(comb) < len(arr[i+j]):
                        arr[i+j] = comb
                    print(arr,j)
                    
                
    
    return arr[target]
print(canSum(8,[3,4,2]))
# Out:
# 0
# [[[]], None, None, [[3]], None, None, None, None, None] 3
# [[[]], None, None, [[3]], [[4]], None, None, None, None] 4
# [[[]], None, [[2]], [[3]], [[4]], None, None, None, None] 2
# 1
# 2
# [[[]], None, [[2]], [[3]], [[4]], [[3, 2]], None, None, None] 3
# [[[]], None, [[2]], [[3]], [[4]], [[3, 2]], [[4, 2]], None, None] 4
# [[[]], None, [[2]], [[3]], [[4]], [[3, 2]], [[4, 2]], None, None] 2
# 3
# [[[]], None, [[2]], [[3]], [[4]], [[3, 2]], [[4, 2]], None, None] 3
# [[[]], None, [[2]], [[3]], [[4]], [[3, 2]], [[4, 2]], [[4, 3]], None] 4
# [[[]], None, [[2]], [[3]], [[4]], [[3, 2]], [[4, 2]], [[4, 3]], None] 2
# 4
# [[[]], None, [[2]], [[3]], [[4]], [[3, 2]], [[4, 2]], [[4, 3]], None] 3
# [[[]], None, [[2]], [[3]], [[4]], [[3, 2]], [[4, 2]], [[4, 3]], [[4, 4]]] 4
# [[[]], None, [[2]], [[3]], [[4]], [[3, 2]], [[4, 2]], [[4, 3]], [[4, 4]]] 2
# 5
# [[[]], None, [[2]], [[3]], [[4]], [[3, 2]], [[4, 2]], [[4, 3]], [[4, 4]]] 3
# [[[]], None, [[2]], [[3]], [[4]], [[3, 2]], [[4, 2]], [[4, 3]], [[4, 4]]] 2
# 6
# [[[]], None, [[2]], [[3]], [[4]], [[3, 2]], [[4, 2]], [[4, 3]], [[4, 4]]] 2
# 7
# 8
# [[4, 4]]

# %%
print(len([[]]))
# Out:
# 1
